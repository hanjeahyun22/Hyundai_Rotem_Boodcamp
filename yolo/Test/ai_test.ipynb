# %%
'''
[문항1] 정렬된 배열에서 가장 빠르게 특정 값을 찾는 탐색 알고리즘은 무엇인지 고르시오.
(배점:5)
1) 선형 탐색 (Linear Search)
2) 이진 탐색 (Binary Search)
3) 버블 정렬 (Bubble Sort)
4) 선택 정렬 (Selection Sort)
'''
# 1 선형 탐색

'''
[문항2] 재귀 호출은 함수 내부에서 자기 자신을 다시 호출하는 프로그래밍 기법이다.
이 때 재귀 호출에서 Recursive case (자기 호출) 외에 반드시 필요한 조건은 무엇인지 고르시오.
(배점:5)
1) 반복문 (Loop)
2) 매개변수 (Parameter)
3) 종료 조건 (Base case)
4) 반환값 (Return value)
'''
# 4) 반환값 (Return value)


'''
[문항3] 입력 크기 n에 대해 중첩 반복문을 사용하는 알고리즘의 시간 복잡도가 O(n²)이라고 할 때, 이 알고리즘의 성능을 가장 정확히 설명한 것은?
(배점:5)
a) 입력이 커질수록 속도가 빨라진다.
b) 입력 크기에 비례해 시간이 선형적으로 증가한다.
c) 입력 크기가 커질수록 속도가 기하급수적으로 느려진다.
d) 입력 크기에 상관없이 항상 일정한 속도를 가진다.
'''
# c) 입력 크기가 커질수록 속도가 기하급수적으로 느려진다.

'''
O자료구조 : 배열, 튜플, 연결리스트, 해시테이블	
[문항4] 데이터가 순서대로 연결되어 있고, 노드와 포인터로 이루어진 선형 자료구조는 무엇인지 고르시오.
(배점:5)
1) 배열
2) 연결 리스트
3) 스택
4) 큐
'''
# 2) 연결 리스트

'''
[문항5] 아래 괄호에 가장 알맞은 용어를 적으시오.

(    )은(는) 정점(Vertex)과 간선(Edge)으로 구성된 자료구조로, DFS(깊이 우선 탐색), BFS(너비 우선 탐색) 등의 알고리즘이 여기에 사용된다. 이 자료구조는 소셜 네트워크 분석, 길찾기(경로 탐색) 등 다양한 분야에서 활용된다.
'''
# 그래프

'''
[문항6] 아래 괄호에 가장 알맞은 용어를 쓰시오.

(    )은(는) 현재 시점에서 가장 좋아 보이는 선택(최적의 선택)을 반복적으로 수행하여 전체 문제의 해답을 찾으려는 알고리즘 설계 전략이다.
이 방법은 각 단계에서의 선택이 전체 최적해로 이어질 것이라는 가정을 기반으로 하며, 거스름돈 문제, 회의실 배정 문제, 배낭 문제(일부 경우) 등에서 자주 사용된다. 하지만 항상 전역 최적해(Global Optimum)를 보장하지는 않는다.
'''
# Greedy Algorithm

'''
[문항7] 아래 괄호에 가장 알맞은 용어를 쓰시오.

(    )은(는) 분할 정복(Divide and Conquer) 방식으로 동작하는 대표적인 정렬 알고리즘이다. 리스트(또는 배열)에서 하나의 기준 값을 선택하고, 이 값을 기준으로 기준 값보다 작은 데이터는 왼쪽, 큰 데이터는 오른쪽으로 나누어 배치한다. 이 과정을 재귀적으로 반복하면서 전체 데이터를 정렬한다.
평균적인 시간 복잡도는 O(n log n) 으로 빠르지만, 기준 값이 한쪽으로 치우치는 경우에는 최악의 시간 복잡도가 O(n²) 이 될 수 있다.

'''
# Quick Sort
# Out:
# '\n[문항7] 아래 괄호에 가장 알맞은 용어를 쓰시오.\n\n(\u2003\u2003\u2003\u2003)은(는) 분할 정복(Divide and Conquer) 방식으로 동작하는 대표적인 정렬 알고리즘이다. 리스트(또는 배열)에서 하나의 기준 값을 선택하고, 이 값을 기준으로 기준 값보다 작은 데이터는 왼쪽, 큰 데이터는 오른쪽으로 나누어 배치한다. 이 과정을 재귀적으로 반복하면서 전체 데이터를 정렬한다.\n평균적인 시간 복잡도는 O(n log n) 으로 빠르지만, 기준 값이 한쪽으로 치우치는 경우에는 최악의 시간 복잡도가 O(n²) 이 될 수 있다.\n\n'

# %%
'''

[문항8] 다음 코드는 리스트의 요소들을 오름차순으로 정렬하여 새로운 리스트에 저장하는 예제이다.
원본 리스트를 변경하지 않고 정렬된 결과를 반환하는 파이썬 내장 함수를 선택하시오.

nums = [5, 1, 4, 2]
result = _______________(nums) # 빈칸
print(result)
'''
nums = [5, 1, 4, 2]
result = sorted(nums) # 빈칸
print(result)
# Out:
# [1, 2, 4, 5]

# %%
'''
[문항9] 다음 이진 탐색 코드에서, 검색 실패 시 가장 일반적인 관례로 반환할 가장 적당한 값을 빈칸에 쓰시오.
(배점:5)
def binary_search(arr, target):
    ...
    return _________    # 빈칸
'''
# -1
# Out:
# '\n[문항9] 다음 이진 탐색 코드에서, 검색 실패 시 가장 일반적인 관례로 반환할 가장 적당한 값을 빈칸에 쓰시오.\n(배점:5)\ndef binary_search(arr, target):\n    ...\n    return _________    # 빈칸\n'

# %%
'''

[문항10] 선형 탐색에서 대상 값을 찾기 위한 if 조건을 완성하시오.
(배점:5)
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == ______________:    # 빈칸
            return i
    return -1
'''
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:    # 빈칸
            return i
    return -1

# %%
'''
[문항11] 대표적인 분할 정복(Divide and Conquer) 기반 정렬 알고리즘인 병합 정렬(Merge Sort)과 퀵 정렬(Quick Sort)은 모두 배열을 분할하여 정렬을 수행하지만, 분할 이후 정렬이 이루어지는 방식에서 차이를 보인다.
두 알고리즘의 핵심적인 차이를 한 문장으로 간단히 설명하시오.
'''
# 배열을 나누는 과정에서 Merge Sort는 "반"으로 나누고, Quick Sort는 "기준값"을 기준으로 나눔


'''
[문항12] 자료구조 중에서 NumPy 배열이 Python 기본 리스트에 비해 연산 속도가 빠른 이유를 세 가지 이상 서술하시오.
'''
# 1. Numpy의 ndarray는 연속된 메모리 블록 활용 -->> CPU는 연속된 메모리를 훨씬 빨리 읽음
# 2. Python에서 직접 반복문을 실행하는 것이 아닌, Numpy 내부의 최적화된 C로 구현된 Universal Function이 연산을 담당
# 3. Python의 GIL(한 번에 하나의 thread만 python코드를 실행하도록 제한) 제약 완화

'''
[문항13] 자료구조 중 스택(Stack)은 후입선출(LIFO, Last In First Out) 구조를 가지는 선형 자료구조로, 다양한 알고리즘과 시스템 설계에서 활용된다.
이러한 스택 구조의 특징을 바탕으로 스택을 사용할 때의 장점에 대해 3가지 이상 설명하시오.
'''
# 1. 가장 나중에 넣은 데이터를 먼저 꺼낼 수 있다. -->> 되돌리기 기능처럼 최근 작업부터 처리할 때 유리
# 2. 구조가 단순 -->> push, pop처럼 넣고 빼는 방식이 간단
# 3. 함수 호출 관리에 유용 -->> 프로그램에서 함수가 실행되고 돌아가는 순서를 관리할 때 사용
# Out:
# '\n[문항13] 자료구조 중 스택(Stack)은 후입선출(LIFO, Last In First Out) 구조를 가지는 선형 자료구조로, 다양한 알고리즘과 시스템 설계에서 활용된다.\n이러한 스택 구조의 특징을 바탕으로 스택을 사용할 때의 장점에 대해 3가지 이상 설명하시오.\n'

# %%
'''

[문항14] 선택 정렬(Selection Sort) 알고리즘을 직접 구현하면서 비교 횟수와 교환 횟수를 세어 출력하는 코드 문제다.
주어진 리스트를 선택 정렬로 오름차순 정렬한 후 아래와 같이 결과를 출력하는 함수를 작성 하시오.
(배점:10)
데이터 : [64, 25, 12, 22, 11]
출력결과는 다음과 같다.
정렬 결과: [11, 12, 22, 25, 64]
비교 횟수: 10
교환 횟수: 3

def selection_sort_with_counts(arr):
    ...
    코드 작성 부분
        ...
    print("정렬 결과:", arr)
    print("비교 횟수:", compare_count)
    print("교환 횟수:", swap_count)

selection_sort_with_counts([64, 25, 12, 22, 11])
'''
def selection_sort_with_counts(arr):
    compare_count = 0
    swap_count = 0

    for i in range(len(arr) - 1):
        min_idx = i
        for j in range(i + 1, len(arr)):
            compare_count += 1

            if arr[j] < arr[min_idx]:
                min_idx = j

        if min_idx != i:
            arr[i], arr[min_idx] = arr[min_idx], arr[i]
            swap_count += 1

    print("정렬 결과:", arr)
    print("비교 횟수:", compare_count)
    print("교환 횟수:", swap_count)

selection_sort_with_counts([64, 25, 12, 22, 11])
# Out:
# 정렬 결과: [11, 12, 22, 25, 64]
# 비교 횟수: 10
# 교환 횟수: 3

# %%
'''

[문항15] 큐(Queue)는 스택과 달리 선입선출(FIFO: First-In First-Out) 구조를 가지는 선형 자료구조로, 먼저 들어온 데이터가 먼저 처리되는 특징을 가진다.
이러한 구조적 특성은 다양한 시스템과 알고리즘에서 활용되지만, 동시에 제한점도 존재한다.
큐 자료구조의 장점과 단점을 각각 2가지 이상 설명하시오.
'''

# 장점
# 1. 먼저 들어온 데이터를 먼저 처리 -->> 작업을 순서대로 처리할 때 좋다.
# 2. 대기열 관리에 적합 -->> 프린터 출력, 주문 처리, 고객 대기열 같은 상황에 잘 맞는다.

# 단점
# 1. 중간에 있는 데이터에 바로 접근하기 어려움 -->> 앞에서부터 차례대로 꺼내야됨
# 2.우선순위 처리가 어려움 -->> 급한 작업이 있어도 큐에서는 먼저 들어온 데이터가 먼저 처리
